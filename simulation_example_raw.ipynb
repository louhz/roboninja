# %%
import matplotlib.pyplot as plt
from cut_simulation.utils.misc import *
from hydra import compose, initialize
from roboninja.env.tc_env import get_cut_env,get_strawberry_env
from roboninja.utils.misc import animate
import pickle


def forward(taichi_env, init_state, comp_actions, grad_enabled, render, **kwargs):
    taichi_env.set_state(init_state, grad_enabled=grad_enabled)

    actions_v = comp_actions[:-1]
    action_p = comp_actions[-1]
    horizon_action = len(actions_v)
    taichi_env.apply_agent_action_p(action_p)
    render_images = list()

    if render: render_images.append(taichi_env.render())
    for i in range(horizon_action):
        taichi_env.step(actions_v[i])
        if render: render_images.append(taichi_env.render())
    loss = taichi_env.get_loss()

    forward_output = {
        'loss': loss,
        'render_images': render_images
    }

    return forward_output


def backward(taichi_env, comp_actions, **kwargs):
    taichi_env.reset_grad()
    taichi_env.get_loss_grad()

    actions_v = comp_actions[:-1]
    horizon_action = len(actions_v)

    for i in range(horizon_action-1, -1, -1):
        taichi_env.step_grad(actions_v[i])
    grad = taichi_env.agent.get_grad(len(actions_v))
    grad[-1][1:] = 0

    backward_output = {
        'grad': grad,
    }

    return backward_output


from hydra.core.global_hydra import GlobalHydra

if GlobalHydra.instance().is_initialized():
    GlobalHydra.instance().clear()

import os
from hydra import compose, initialize_config_dir
from hydra.core.global_hydra import GlobalHydra

GlobalHydra.instance().clear()

config_dir = os.path.abspath("roboninja/config/cut_env")
initialize_config_dir(config_dir=config_dir, version_base=None)

cfg = compose(config_name="cut_env_strawberry")
# cfg = compose(config_name='cut_env')
bone_idx = 0

# cfg.strawberry.splat_path = "/home/louhz/Desktop/Rss/roboninja/generateddata/Generated_strawberry/0001/gaussian.ply"
cfg.strawberry.mesh_path = "/home/louhz/Desktop/Rss/roboninja/generateddata/Generated_strawberry/0001/mesh.obj"
cfg.strawberry.pos = (0.5, 0.1, 0.45)  #(x,z,y)
cfg.strawberry.scale = (0.25, 0.25, 0.25)

cfg.strawberry.voxelize_res = 256
cfg.strawberry.shell_radius_vox = 2
cfg.strawberry.close_iters = 2
cfg.strawberry.normalize = True
cfg.strawberry.trim_percentile = 0.5
cfg.strawberry.cache_voxels = True
cfg.strawberry.euler = (0.0, 180.0, 0.0)
cfg.auto_boundary = True

cfg.bone.name = f'bone_{bone_idx}'
taichi_env = get_strawberry_env(cfg)

knife = taichi_env.agent.effectors[0]

# set some constant
horizon_action = 60

# set init actions
init_action_p = np.asarray([-0.6, 0.155, 0.5])
init_action_v = np.asarray([[0., 0., 0.]] * horizon_action)
init_action_v[:int(horizon_action * 0.4), 1] = -0.3
init_actions = np.concatenate([init_action_v, init_action_p[None]], axis=0)

init_state = taichi_env.get_state()['state']
current_actions = init_actions


kwargs = {
    'taichi_env': taichi_env,
    'init_state': init_state,
    'comp_actions': current_actions,
    'grad_enabled': True,
    'render': True
}
# Out:
# [Taichi] version 1.7.4, llvm 15.0.4, commit b4b956fd, linux, python 3.10.18
# [I 01/23/26 02:39:56.966 10168] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=cuda
# ===>     3466 particles of strawberry     mesh added.
# /home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/ui/scene.py:460: DeprecationWarning: Instantiating ti.ui.Scene directly is deprecated, use the get_scene() function from a taichi.ui.Window object instead.
#   warnings.warn(

# %% [markdown]
# read the strawberry
#
#
# fix the scale and relative pose for the fruit, scene, obtain the relative final pose for the knife and the strawberry, also compute the knife cutting trajectory with relative to the strawberry
#
#
# replace the knife and strawberry and cutting traejectory in the roboninja simulation.
#
# Then simulate the moving of the particel
#
#
#
#
# Then design the custom reward for different strawberry size
#
#
#
#  compute the relationship between the knife and the end effector
#
#  compute ik for different relative pose of the knife and the strawberry and shape of strawberry
#
#
#  batchify generate data for control
#
#
#  test it in genesis for collision avoidance
#
#
# Then add the tactile simulation on the side of this two strawberry and near knife(optional)
#
#
#  deploy to real world (test the validness of our data, for the rl   )

# %% [markdown]
# training logic:  query state(no privilage information)
#
#
# (based on the verified data)
#
# multi-stage
#
# ee+hand seperate
#
# adaptive chunking size
#
#
# we have data for the strayberry and hand
#
#
# we need more data for the end effector pose varies

# %% [markdown]
# render image

# %%
plt.imshow(taichi_env.render())
# Out:
# [I 01/23/26 02:40:18.033 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...

# %% [markdown]
# forward pass using the initial trajectory

# %%
forward_output = forward(**kwargs)
print(forward_output['loss'])
animate(forward_output['render_images'], 'videos/initial_trajectory.mp4')
# Out:
# [I 01/23/26 02:40:20.027 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.388 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.421 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.455 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.488 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.521 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.555 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.588 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.622 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.655 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.687 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.719 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.751 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.783 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.815 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.849 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.882 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.916 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.949 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:27.983 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.016 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.050 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.083 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.117 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.150 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.184 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.217 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.250 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.283 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.316 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.348 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.384 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.418 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.451 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.484 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.516 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.550 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.582 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.614 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.647 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.681 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.715 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.747 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.780 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.813 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.845 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.879 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.912 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.946 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:28.979 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.013 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.046 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.080 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.113 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.146 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.179 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.212 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.245 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.277 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.309 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:40:29.341 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# {'loss': 0.42780593304659714, 'cut_loss': 0.009538883207369713, 'collision_loss': 1.658880233179616e-06, 'rotation_loss': 0.0, 'move_loss': 0.0, 'work_loss': 0.00042736955798452423, 'work_curve': array([0.00160234, 0.00043973, 0.00057281, ..., 0.        , 0.        ,
#        0.        ])}
# <video src="videos/initial_trajectory.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# compute action gradient w.r.t. loss

# %%
backward_output = backward(**kwargs)
gradient = backward_output['grad']
# Out:
# [W 01/23/26 02:41:37.548 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 2562 before anything is stored to it.
# [W 01/23/26 02:41:37.549 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 2564 before anything is stored to it.
# [W 01/23/26 02:41:37.609 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 3266 before anything is stored to it.
# [W 01/23/26 02:41:37.610 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 3268 before anything is stored to it.
# [W 01/23/26 02:41:37.678 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 3970 before anything is stored to it.
# [W 01/23/26 02:41:37.678 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/static.py", line 73, in normal_:
#             normal_vec[i] = (self.sdf_(inc) - self.sdf_(dec)) / (2 * delta)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 3972 before anything is stored to it.
# [W 01/23/26 02:41:37.681 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4062 before anything is stored to it.
# [W 01/23/26 02:41:37.682 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4064 before anything is stored to it.
# [W 01/23/26 02:41:37.683 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4076 before anything is stored to it.
# [W 01/23/26 02:41:37.684 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4078 before anything is stored to it.
# [W 01/23/26 02:41:37.685 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4090 before anything is stored to it.
# [W 01/23/26 02:41:37.686 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4092 before anything is stored to it.
# [W 01/23/26 02:41:37.687 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4103 before anything is stored to it.
# [W 01/23/26 02:41:37.688 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4105 before anything is stored to it.
# [W 01/23/26 02:41:37.689 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4117 before anything is stored to it.
# [W 01/23/26 02:41:37.690 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4119 before anything is stored to it.
# [W 01/23/26 02:41:37.691 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4131 before anything is stored to it.
# [W 01/23/26 02:41:37.692 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4133 before anything is stored to it.
# [W 01/23/26 02:41:37.693 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4144 before anything is stored to it.
# [W 01/23/26 02:41:37.694 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                                       ^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4146 before anything is stored to it.
# [W 01/23/26 02:41:37.696 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4158 before anything is stored to it.
# [W 01/23/26 02:41:37.696 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4160 before anything is stored to it.
# [W 01/23/26 02:41:37.698 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4172 before anything is stored to it.
# [W 01/23/26 02:41:37.699 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/anaconda3/envs/roboninja/lib/python3.10/site-packages/taichi/lang/matrix_ops.py", line 274, in _matmul_helper:
#                 vec_z[i] = vec_z[i] + mat_x[i, j] * mat_y[j]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4174 before anything is stored to it.
# [W 01/23/26 02:41:37.757 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4806 before anything is stored to it.
# [W 01/23/26 02:41:37.758 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4809 before anything is stored to it.
# [W 01/23/26 02:41:37.759 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4811 before anything is stored to it.
# [W 01/23/26 02:41:37.759 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4816 before anything is stored to it.
# [W 01/23/26 02:41:37.760 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4819 before anything is stored to it.
# [W 01/23/26 02:41:37.761 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/utils/geom.py", line 98, in transform_by_quat_ti:
#     return v + 2 * (quat[0] * uv + uuv)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 4821 before anything is stored to it.
# [W 01/23/26 02:41:37.795 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5173 before anything is stored to it.
# [W 01/23/26 02:41:37.796 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5175 before anything is stored to it.
# [W 01/23/26 02:41:37.797 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5184 before anything is stored to it.
# [W 01/23/26 02:41:37.797 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5187 before anything is stored to it.
# [W 01/23/26 02:41:37.798 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5189 before anything is stored to it.
# [W 01/23/26 02:41:37.799 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5194 before anything is stored to it.
# [W 01/23/26 02:41:37.800 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5197 before anything is stored to it.
# [W 01/23/26 02:41:37.801 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5199 before anything is stored to it.
# [W 01/23/26 02:41:37.839 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5550 before anything is stored to it.
# [W 01/23/26 02:41:37.840 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5552 before anything is stored to it.
# [W 01/23/26 02:41:37.841 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5561 before anything is stored to it.
# [W 01/23/26 02:41:37.842 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5564 before anything is stored to it.
# [W 01/23/26 02:41:37.843 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5566 before anything is stored to it.
# [W 01/23/26 02:41:37.844 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5571 before anything is stored to it.
# [W 01/23/26 02:41:37.844 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5574 before anything is stored to it.
# [W 01/23/26 02:41:37.845 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5576 before anything is stored to it.
# [W 01/23/26 02:41:37.884 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5927 before anything is stored to it.
# [W 01/23/26 02:41:37.885 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 62, in normal_knife_:
#             normal_vec[i] = (self.sdf_knife_(inc) - self.sdf_knife_(dec)) / (2 *
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Loading variable 5929 before anything is stored to it.
# [W 01/23/26 02:41:37.903 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/meshes/dynamic.py", line 113, in normal:
#         if isnan(normal_vec_world[0]):
#                  ^^^^^^^^^^^^^^^^^^^
# Loading variable 6039 before anything is stored to it.
# [W 01/23/26 02:41:37.917 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 396, in grid_op:
#                     if I[d] < bound and v_out[d] < 0:
#                                         ^^^^^^^^
# Loading variable 6152 before anything is stored to it.
# [W 01/23/26 02:41:37.917 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6160 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6159 before anything is stored to it.
# [W 01/23/26 02:41:37.918 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6162 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6161 before anything is stored to it.
# [W 01/23/26 02:41:37.919 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 412, in grid_op:
#                     if I[d] > self.res[d] - bound and v_out[d] > 0:
#                                                       ^^^^^^^^
# Loading variable 6172 before anything is stored to it.
# [W 01/23/26 02:41:37.920 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6180 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6179 before anything is stored to it.
# [W 01/23/26 02:41:37.920 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6182 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6181 before anything is stored to it.
# [W 01/23/26 02:41:37.922 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 396, in grid_op:
#                     if I[d] < bound and v_out[d] < 0:
#                                         ^^^^^^^^
# Loading variable 6192 before anything is stored to it.
# [W 01/23/26 02:41:37.922 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6202 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6201 before anything is stored to it.
# [W 01/23/26 02:41:37.923 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6204 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6203 before anything is stored to it.
# [W 01/23/26 02:41:37.929 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 412, in grid_op:
#                     if I[d] > self.res[d] - bound and v_out[d] > 0:
#                                                       ^^^^^^^^
# Loading variable 6264 before anything is stored to it.
# [W 01/23/26 02:41:37.930 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6272 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6271 before anything is stored to it.
# [W 01/23/26 02:41:37.931 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6274 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6273 before anything is stored to it.
# [W 01/23/26 02:41:37.932 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 396, in grid_op:
#                     if I[d] < bound and v_out[d] < 0:
#                                         ^^^^^^^^
# Loading variable 6284 before anything is stored to it.
# [W 01/23/26 02:41:37.933 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6292 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6291 before anything is stored to it.
# [W 01/23/26 02:41:37.933 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6294 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6293 before anything is stored to it.
# [W 01/23/26 02:41:37.934 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, File "/home/louhz/Desktop/Rss/roboninja/cut_simulation/engine/simulators/mpm_simulator.py", line 412, in grid_op:
#                     if I[d] > self.res[d] - bound and v_out[d] > 0:
#                                                       ^^^^^^^^
# Loading variable 6304 before anything is stored to it.
# [W 01/23/26 02:41:37.935 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6312 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6311 before anything is stored to it.
# [W 01/23/26 02:41:37.936 10213] TaichiWarning
# While compiling `grid_op_c97_0_reverse_grad`, Statement $6314 (type=taichi::lang::LocalLoadStmt);
# Loading variable 6313 before anything is stored to it.

# %% [markdown]
# directly load the optimized trajectory

# %%
data = pickle.load(open(f'data/expert/expert_{bone_idx}/optimization.pkl', 'rb'))
kwargs['comp_actions'] = data[-1]['comp_actions']
forward_output = forward(**kwargs)
animate(forward_output['render_images'], 'videos/optimized_trajectory.mp4')
# Out:
# [I 01/23/26 02:44:32.415 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.448 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.480 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.513 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.545 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.580 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.613 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.651 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.686 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.722 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.754 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.786 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.819 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.850 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.883 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.917 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.948 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:32.982 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.014 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.046 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.079 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.111 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.145 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.178 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.213 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.247 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.282 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.318 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.355 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.389 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.424 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.461 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.496 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.531 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.567 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.602 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.636 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.672 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.707 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.742 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.778 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.813 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.847 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.881 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.914 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.947 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:33.982 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.021 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.056 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.090 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.124 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.161 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.196 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.231 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.270 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.305 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.340 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.375 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.410 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.446 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# [I 01/23/26 02:44:34.480 10168] [swap_chain.cpp:dump_image_buffer@164] Dumping image buffer...
# <video src="videos/optimized_trajectory.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
